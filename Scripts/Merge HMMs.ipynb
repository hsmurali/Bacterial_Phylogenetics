# %%
from os import listdir

# %%
merged_hmms = open('/Users/harihara/UMD_Coursework/Fall_2021/CMSC829A/Project/Data/Accessory_Genes.hmm','w')
hmm_dir = '/Users/harihara/Mount/CMSC829A/Data/Accessory_Genes_Proteins_MSA_HMM/'
hmms = listdir(hmm_dir)

for h in hmms:
    if h[0] != '.':
        print(h)
        s = open(hmm_dir+h, 'r').read()
        merged_hmms.write(s)
merged_hmms.close()
# Out:
# dppD.hmm
# bshC.hmm
# cobS.hmm
# hisD.hmm
# rtcA.hmm
# tyrR.hmm
# urtA.hmm
# yncL.hmm
# entD.hmm
# fdrA.hmm
# yiaK.hmm
# symE.hmm
# choW.hmm
# fdhA.hmm
# rmuC.hmm
# gcl.hmm
# mgtR.hmm
# waaA.hmm
# mqo.hmm
# dcuR.hmm
# sodB.hmm
# rrtA.hmm
# kefG.hmm
# pduH.hmm
# moaB.hmm
# proB.hmm
# mdcG.hmm
# ureA.hmm
# pat.hmm
# rdgC.hmm
# rsmF.hmm
# narI.hmm
# nudB.hmm
# queF.hmm
# asmA.hmm
# yebS.hmm
# ispF.hmm
# coaC.hmm
# slyB.hmm
# priC.hmm
# hutX.hmm
# fpr.hmm
# srmB.hmm
# yihX.hmm
# zntB.hmm
# aaeA.hmm
# truA.hmm
# fusA.hmm
# hyaB.hmm
# mtgA.hmm
# bamC.hmm
# selB.hmm
# cspE.hmm
# xapA.hmm
# dld.hmm
# minC.hmm
# ytfQ.hmm
# trbB.hmm
# stpA.hmm
# sltY.hmm
# fadM.hmm
# zur.hmm
# cmtB.hmm
# sopD2.hmm
# lon.hmm
# phnT.hmm
# mreD.hmm
# tkt.hmm
# poxB.hmm
# zupT.hmm
# aspS.hmm
# copZ.hmm
# sodC.hmm
# eat.hmm
# frdA.hmm
# rcsC.hmm
# dadA.hmm
# atzF.hmm
# bcfC.hmm
# yihI.hmm
# flhA.hmm
# mltG.hmm
# gluQRS.hmm
# aphA.hmm
# mtaB.hmm
# htpG.hmm
# yohP.hmm
# mngB.hmm
# sufA.hmm
# mukE.hmm
# feoB.hmm
# ...
